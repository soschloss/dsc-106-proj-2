# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
fp = Path('data') / 'nypd-data.csv'
df = pd.read_csv(fp)
df
# Out:
#        unique_mos_id first_name last_name command_now  shield_no  \
# 0              10004   Jonathan      Ruiz     078 PCT       8409
# 1              10007       John     Sears     078 PCT       5952
# 2              10007       John     Sears     078 PCT       5952
# 3              10007       John     Sears     078 PCT       5952
# 4              10009      Noemi    Sierra     078 PCT      24058
# ...              ...        ...       ...         ...        ...
# 33353           9992     Tomasz  Pulawski     078 PCT       2642
# 33354           9992     Tomasz  Pulawski     078 PCT       2642
# 33355           9992     Tomasz  Pulawski     078 PCT       2642
# 33356           9992     Tomasz  Pulawski     078 PCT       2642
# 33357           9992     Tomasz  Pulawski     078 PCT       2642
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 0             42835               7           2019             5         2020
# ...

# %%
df.groupby(['complainant_ethnicity', 'fado_type']).size()
# Out:
# complainant_ethnicity  fado_type
# American Indian        Abuse of Authority       48
#                        Discourtesy               8
#                        Force                     7
#                        Offensive Language        1
# Asian                  Abuse of Authority      330
#                        Discourtesy              86
#                        Force                    96
#                        Offensive Language       20
# Black                  Abuse of Authority    10359
#                        Discourtesy            2290
#                        Force                  4072
#                        Offensive Language      393
# Hispanic               Abuse of Authority     3676
#                        Discourtesy            1026
#                        Force                  1596
#                        Offensive Language      126
# Other Race             Abuse of Authority      390
#                        Discourtesy             124
# ...

# %%
df['full_name'] = df['first_name'] + ' ' + df['last_name']
officer_shields = df.groupby('shield_no').size().sort_values(ascending=False)
officer_names = df.groupby('full_name').size().sort_values(ascending=False)
officer_names.head(10)
# Out:
# full_name
# Daniel Sbarra           75
# Mathew Reich            75
# Gary Messina            73
# Joseph Tallarine        73
# Christophe Mccormack    72
# William Taylor          65
# David Cheesewright      63
# Paul Mcmahon            56
# Mike Civil              56
# Michael Raso            50
# dtype: int64

# %%
shield_zero = df[df['shield_no'] == 0]
shield_zero
# Out:
#        unique_mos_id first_name last_name command_now  shield_no  \
# 214            10134      James      Hart     079 PCT          0
# 215            10134      James      Hart     079 PCT          0
# 216            10134      James      Hart     079 PCT          0
# 217            10134      James      Hart     079 PCT          0
# 218            10134      James      Hart     079 PCT          0
# ...              ...        ...       ...         ...        ...
# 33334           9965    Colbert    Martin     078 PCT          0
# 33335           9965    Colbert    Martin     078 PCT          0
# 33342           9979   Novaidul      Neon     078 PCT          0
# 33343           9979   Novaidul      Neon     078 PCT          0
# 33344           9979   Novaidul      Neon     078 PCT          0
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 214           24367              10           2011             8         2012
# ...
